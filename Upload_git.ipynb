# %% [markdown]
# # Uplod an project to github
# ### 1) Mount gdrive and go to folder of project

# %%
# Mount to google drive into colab environement
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %cd gdrive/My\ Drive/Colab_project/project_test
# !pwd
# !find .
# Out:
# /content/gdrive/My Drive/Colab_project/project_test
# /content/gdrive/My Drive/Colab_project/project_test
# .
# ./Upload_git.ipynb
# ./file_stokage
# ./file_stokage/Untitled document.gdoc
# ./file_stokage/Hello_World.gdoc
# ./package

# %%
# !echo "here is an example" >>package/textfile.txt

# %%
# !git config --global user.name "Willson-Dev-Root"
# !git config --global user.email "dev.root.vl92@gmail.com"
# !git config --global --list
# Out:
# user.name=Willson-Dev-Root
# user.email=dev.root.vl92@gmail.com

# %%
# !git init
# !git add .
# !git commit -a -m "First commit. Create the projet"
# !git remote add origin https://Willson-Dev-Root:Son50!102@github.com/Willson-Dev-Root/Test_push_pro.git
# !git remote -v
# Out:
# Initialized empty Git repository in /content/gdrive/My Drive/Colab_project/project_test/.git/
# error: open("file_stokage/Hello_World.gdoc"): Operation not supported
# error: unable to index file file_stokage/Hello_World.gdoc
# fatal: adding files failed
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@74d3ce0abd1a.(none)')
# origin	https://Willson-Dev-Root:Son50!102@github.com/Willson-Dev-Root/Test_push_pro.git (fetch)
# origin	https://Willson-Dev-Root:Son50!102@github.com/Willson-Dev-Root/Test_push_pro.git (push)

# %%
# !git add .
# !git commit -m "First commit. Create the projet"
# Out:
# [master (root-commit) d33de8f] First commit. Create the projet
#  3 files changed, 4 insertions(+)
#  create mode 100644 Upload_git.ipynb
#  create mode 100644 file_stokage/variable_active.txt
#  create mode 100644 package/textfile.txt

# %%
# !git push origin master
# !git merge master
# Out:
# Counting objects: 7, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (7/7), 2.13 KiB | 363.00 KiB/s, done.
# Total 7 (delta 0), reused 0 (delta 0)
# To https://github.com/Willson-Dev-Root/Test_push_pro.git
#  * [new branch]      master -> master
# Already up to date.

# %%
# !git pull
# Out:
# There is no tracking information for the current branch.
# Please specify which branch you want to merge with.
# See git-pull(1) for details.
#
#     git pull <remote> <branch>
#
# If you wish to set tracking information for this branch you can do so with:
#
#     git branch --set-upstream-to=origin/<branch> master

# %%
# !git add .
# !git commit -m "First commit. Create the projet"
# !git push origin master
# !git merge master
